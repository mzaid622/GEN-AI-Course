# %%
from langchain_core.tools import tool
from langchain_ollama import ChatOllama
import requests

# %%
llm = ChatOllama(model="llama3.2:3b")

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()
# Out:
# C:\Users\MZaid\AppData\Local\Temp\ipykernel_15884\2272844035.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun

# %%
results = search_tool.invoke('top news in pakistan today')
print(results)
# Out:
# Read today's breaking national news from Pakistan. Daily headlines on politics, current affairs, security updates, and local stories in high-quality Urdu. PTV News LIVE | 24/7 Coverage | Headlines, Bulletins & Breaking NewsWelcome to the official PTV News YouTube Channel - Pakistan's most reliable destination f... Read today's top Pakistan headlines, breaking news stories, political updates, business news, sports coverage, and international affairs. The Express Tribune Today's Newspaper, Read online Newspaper of Pakistan - anywhere, anytime. Home » Top Headlines Top Headlines Govt hikes petrol price by Rs4.45, decreases HSD by Rs2 Pakistan, Iran deepen economic partnership, target $10bn trade through border, FTA push

# %%
llm.invoke("Hi")
# Out:
# AIMessage(content='How can I assist you today?', additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2026-08-06T07:35:58.8357022Z', 'done': True, 'done_reason': 'stop', 'total_duration': 12123941100, 'load_duration': 8952052700, 'prompt_eval_count': 26, 'prompt_eval_duration': 1353677000, 'eval_count': 8, 'eval_duration': 1793142000, 'logprobs': None, 'model_name': 'llama3.2:3b', 'model_provider': 'ollama'}, id='lc_run--019fd5ff-eb0f-7ce2-8f85-457697eedda4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 8, 'total_tokens': 34})

# %%
from langchain.agents import create_agent
from langchain_classic.agents import AgentExecutor
# Replace 'from langchain import hub' with:
from langchain_classic import hub

# %%
# Step 2: Pull the ReAct prompt from LangChain Hub
prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
# Out:
# C:\Users\MZaid\AppData\Local\Temp\ipykernel_15884\3720386481.py:2: LangChainDeprecationWarning: langchain_classic.hub.pull is deprecated. Use the LangSmith SDK instead.
#   prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Step 2: Pull the ReAct prompt from LangChain Hub
# ----> 2 prompt = hub.pull("hwchase17/react")  # pulls the standard ReAct agent prompt
#
# File d:\GEN-AI-Course\venv\Lib\site-packages\langchain_core\_api\deprecation.py:237, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     234     # Only mark the warning as emitted if it was not intentionally
#     235     # suppressed by `suppress_langchain_deprecation_warning()`.
#     236     warned = not _SUPPRESSING_LANGCHAIN_DEPRECATION_WARNING.get()
# --> 237 return wrapped(*args, **kwargs)
#
# File d:\GEN-AI-Course\venv\Lib\site-packages\langchain_classic\hub.py:117, in pull(owner_repo_commit, include_model, api_url, api_key)
#      76 """Pull an object from the hub and returns it as a LangChain object.
#      77
#      78 !!! danger "Hub manifests are untrusted input"
#    (...)    114     The pulled LangChain object.
#     115 """
#     116 client = LangSmithClient(api_url, api_key=api_key)
# --> 117 return client.pull_prompt(owner_repo_commit, include_model=include_model)
#
# File d:\GEN-AI-Course\venv\Lib\site-packages\langsmith\client.py:9651, in Client.pull_prompt(self, prompt_identifier, include_model, secrets, secrets_from_env, skip_cache, dangerously_pull_public_prompt)
#    9647             [GHSA-c67j-w6g6-q2cm](https://github.com/langchain-ai/langchain/security/advisories/GHSA-c67j-w6g6-q2cm)
#    9648             in the `langchain-core` package which this method (but not the entire
#    9649             langsmith package) depends on.
#    9650         """
# -> 9651         prompt_object = self.pull_prompt_commit(
#    9652             prompt_identifier,
#    9653             include_model=include_model,
#    9654             skip_cache=skip_cache,
#
# File d:\GEN-AI-Course\venv\Lib\site-packages\langsmith\client.py:9499, in Client.pull_prompt_commit(self, prompt_identifier, include_model, skip_cache, dangerously_pull_public_prompt)
#    9495
#    9496         Raises:
#    9497             ValueError: If no commits are found for the prompt.
#    9498         """
# -> 9499         _validate_public_prompt_pull(
#    9500             prompt_identifier,
#    9501             dangerously_pull_public_prompt=dangerously_pull_public_prompt,
#    9502         )
#
# File d:\GEN-AI-Course\venv\Lib\site-packages\langsmith\client.py:387, in _validate_public_prompt_pull(prompt_identifier, dangerously_pull_public_prompt)
#     383     prompt_identifier: str, *, dangerously_pull_public_prompt: bool
#     384 ) -> None:
#     385     owner, _, _ = ls_utils.parse_prompt_identifier(prompt_identifier)
#     386     if owner != "-" and not dangerously_pull_public_prompt:
# --> 387         raise ValueError(
#     388             "Pulling a public prompt by owner/name is disabled by default because "
#     389             "prompts may contain untrusted serialized LangChain objects. If you "
#     390             "trust this prompt, set `dangerously_pull_public_prompt=True` to "
#
# ValueError: Pulling a public prompt by owner/name is disabled by default because prompts may contain untrusted serialized LangChain objects. If you trust this prompt, set `dangerously_pull_public_prompt=True` to acknowledge the risk.
